# %%
import pandas as pd
import numpy as np
import glob
import os
import re
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
stopword = nltk.corpus.stopwords.words('english')
wn=nltk.WordNetLemmatizer()
st=nltk.PorterStemmer()

# %%
def clean(text):
    s = re.sub(r'Description ', '',text) 
    s = re.sub(r' show more', '',s).strip().lower()
    text=re.sub(r'[^\w\s]',' ',s).lower()   ### Remove punctuation by removing non-space alpha-num characters
    words=re.split(r'\W+', text) ### Split by remaining non-alphanumeric characters
    non_stop_words=[word for word in words if word not in stopword]        ### Remove stopwords
    lem_words= [wn.lemmatize(word) for word in non_stop_words]             ### Clean text ==
    clean_text= ' '.join(lem_words)
    return clean_text

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts
files = []
for infile in sorted(glob.glob('*_info.txt'), key=numericalSort):
    files.append(infile)
# Out:
# 100_info.txt
# 101_info.txt
# 102_info.txt
# 103_info.txt
# 104_info.txt
# 105_info.txt
# 106_info.txt
# 107_info.txt
# 108_info.txt
# 109_info.txt
# 10_info.txt
# 110_info.txt
# 111_info.txt
# 112_info.txt
# 113_info.txt
# 114_info.txt
# 115_info.txt
# 116_info.txt
# 117_info.txt
# 118_info.txt
# 119_info.txt
# 11_info.txt
# 120_info.txt
# 121_info.txt
# 122_info.txt
# 123_info.txt
# 124_info.txt
# 125_info.txt
# 126_info.txt
# 127_info.txt
# 128_info.txt
# 129_info.txt
# 12_info.txt
# 130_info.txt
# 131_info.txt
# 132_info.txt
# 133_info.txt
# 134_info.txt
# 135_info.txt
# 136_info.txt
# 137_info.txt
# 138_info.txt
# 139_info.txt
# 13_info.txt
# 140_info.txt
# 141_info.txt
# 142_info.txt
# 143_info.txt
# 144_info.txt
# 145_info.txt
# 146_info.txt
# 147_info.txt
# 148_info.txt
# 149_info.txt
# 14_info.txt
# 150_info.txt
# 151_info.txt
# 152_info.txt
# 153_info.txt
# 154_info.txt
# 155_info.txt
# 156_info.txt
# 157_info.txt
# 158_info.txt
# 159_info.txt
# 15_info.txt
# 160_info.txt
# 161_info.txt
# 162_info.txt
# 163_info.txt
# 164_info.txt
# 165_info.txt
# 166_info.txt
# 167_info.txt
# 168_info.txt
# 169_info.txt
# 16_info.txt
# 170_info.txt
# 171_info.txt
# 172_info.txt
# 173_info.txt
# 174_info.txt
# 175_info.txt
# 176_info.txt
# 177_info.txt
# 178_info.txt
# 179_info.txt
# 17_info.txt
# 180_info.txt
# 181_info.txt
# 182_info.txt
# 183_info.txt
# 184_info.txt
# 185_info.txt
# 186_info.txt
# 187_info.txt
# 188_info.txt
# 189_info.txt
# 18_info.txt
# 190_info.txt
# 191_info.txt
# 192_info.txt
# 193_info.txt
# 194_info.txt
# 195_info.txt
# 196_info.txt
# 197_info.txt
# 198_info.txt
# 199_info.txt
# 19_info.txt
# 1_info.txt
# 200_info.txt
# 201_info.txt
# 202_info.txt
# 203_info.txt
# 204_info.txt
# 205_info.txt
# 206_info.txt
# 207_info.txt
# 208_info.txt
# 209_info.txt
# 20_info.txt
# 210_info.txt
# 211_info.txt
# 212_info.txt
# 213_info.txt
# 214_info.txt
# 215_info.txt
# 216_info.txt
# 217_info.txt
# 218_info.txt
# 219_info.txt
# 21_info.txt
# 220_info.txt
# 221_info.txt
# 222_info.txt
# 223_info.txt
# 224_info.txt
# 225_info.txt
# 226_info.txt
# 227_info.txt
# 228_info.txt
# 229_info.txt
# 22_info.txt
# 230_info.txt
# 231_info.txt
# 232_info.txt
# 233_info.txt
# 234_info.txt
# 235_info.txt
# 236_info.txt
# 237_info.txt
# 238_info.txt
# 239_info.txt
# 23_info.txt
# 240_info.txt
# 241_info.txt
# 242_info.txt
# 243_info.txt
# 244_info.txt
# 245_info.txt
# 246_info.txt
# 247_info.txt
# 248_info.txt
# 249_info.txt
# 24_info.txt
# 250_info.txt
# 251_info.txt
# 252_info.txt
# 253_info.txt
# 254_info.txt
# 255_info.txt
# 256_info.txt
# 257_info.txt
# 258_info.txt
# 259_info.txt
# 25_info.txt
# 260_info.txt
# 261_info.txt
# 262_info.txt
# 263_info.txt
# 264_info.txt
# 265_info.txt
# 266_info.txt
# 267_info.txt
# 268_info.txt
# 269_info.txt
# 26_info.txt
# 270_info.txt
# 271_info.txt
# 272_info.txt
# 273_info.txt
# 274_info.txt
# 275_info.txt
# 276_info.txt
# 277_info.txt
# 278_info.txt
# 279_info.txt
# 27_info.txt
# 280_info.txt
# 281_info.txt
# 282_info.txt
# 283_info.txt
# 284_info.txt
# 285_info.txt
# 286_info.txt
# 287_info.txt
# 288_info.txt
# 289_info.txt
# 28_info.txt
# 290_info.txt
# 291_info.txt
# 292_info.txt
# 293_info.txt
# 294_info.txt
# 295_info.txt
# 296_info.txt
# 297_info.txt
# 298_info.txt
# 299_info.txt
# 29_info.txt
# 2_info.txt
# 300_info.txt
# 301_info.txt
# 302_info.txt
# 303_info.txt
# 304_info.txt
# 305_info.txt
# 306_info.txt
# 307_info.txt
# 308_info.txt
# 309_info.txt
# 30_info.txt
# 310_info.txt
# 311_info.txt
# 312_info.txt
# 313_info.txt
# 314_info.txt
# 315_info.txt
# 316_info.txt
# 317_info.txt
# 318_info.txt
# 319_info.txt
# 31_info.txt
# 320_info.txt
# 321_info.txt
# 322_info.txt
# 323_info.txt
# 324_info.txt
# 325_info.txt
# 326_info.txt
# 327_info.txt
# 328_info.txt
# 329_info.txt
# 32_info.txt
# 330_info.txt
# 331_info.txt
# 332_info.txt
# 333_info.txt
# 334_info.txt
# 335_info.txt
# 336_info.txt
# 337_info.txt
# 338_info.txt
# 339_info.txt
# 33_info.txt
# 340_info.txt
# 341_info.txt
# 342_info.txt
# 343_info.txt
# 344_info.txt
# 345_info.txt
# 346_info.txt
# 347_info.txt
# 348_info.txt
# 349_info.txt
# 34_info.txt
# 350_info.txt
# 351_info.txt
# 352_info.txt
# 353_info.txt
# 354_info.txt
# 355_info.txt
# 356_info.txt
# 357_info.txt
# 358_info.txt
# 359_info.txt
# 35_info.txt
# 360_info.txt
# 361_info.txt
# 362_info.txt
# 363_info.txt
# 364_info.txt
# 365_info.txt
# 366_info.txt
# 367_info.txt
# 368_info.txt
# 369_info.txt
# 36_info.txt
# 370_info.txt
# 371_info.txt
# 372_info.txt
# 373_info.txt
# 374_info.txt
# 375_info.txt
# 376_info.txt
# 377_info.txt
# 378_info.txt
# 379_info.txt
# 37_info.txt
# 380_info.txt
# 381_info.txt
# 382_info.txt
# 383_info.txt
# 384_info.txt
# 385_info.txt
# 386_info.txt
# 387_info.txt
# 388_info.txt
# 389_info.txt
# 38_info.txt
# 390_info.txt
# 391_info.txt
# 392_info.txt
# 393_info.txt
# 394_info.txt
# 395_info.txt
# 396_info.txt
# 397_info.txt
# 398_info.txt
# 399_info.txt
# 39_info.txt
# 3_info.txt
# 400_info.txt
# 401_info.txt
# 402_info.txt
# 403_info.txt
# 404_info.txt
# 405_info.txt
# 406_info.txt
# 407_info.txt
# 408_info.txt
# 409_info.txt
# 40_info.txt
# 410_info.txt
# 411_info.txt
# 412_info.txt
# 413_info.txt
# 414_info.txt
# 415_info.txt
# 416_info.txt
# 41_info.txt
# 42_info.txt
# 43_info.txt
# 44_info.txt
# 45_info.txt
# 46_info.txt
# 47_info.txt
# 48_info.txt
# 49_info.txt
# 4_info.txt
# 50_info.txt
# 51_info.txt
# 52_info.txt
# 53_info.txt
# 54_info.txt
# 55_info.txt
# 56_info.txt
# 57_info.txt
# 58_info.txt
# 59_info.txt
# 5_info.txt
# 60_info.txt
# 61_info.txt
# 62_info.txt
# 63_info.txt
# 64_info.txt
# 65_info.txt
# 66_info.txt
# 67_info.txt
# 68_info.txt
# 69_info.txt
# 6_info.txt
# 70_info.txt
# 71_info.txt
# 72_info.txt
# 73_info.txt
# 74_info.txt
# 75_info.txt
# 76_info.txt
# 77_info.txt
# 78_info.txt
# 79_info.txt
# 7_info.txt
# 80_info.txt
# 81_info.txt
# 82_info.txt
# 83_info.txt
# 84_info.txt
# 85_info.txt
# 86_info.txt
# 87_info.txt
# 88_info.txt
# 89_info.txt
# 8_info.txt
# 90_info.txt
# 91_info.txt
# 92_info.txt
# 93_info.txt
# 94_info.txt
# 95_info.txt
# 96_info.txt
# 97_info.txt
# 98_info.txt
# 99_info.txt
# 9_info.txt

# %%
for file in files:
    with open(file,'r',encoding="utf8") as f:
        data=f.read().split('\n\n')
        data=[i.split('\n') for i in data]
        s=pd.DataFrame([data[0][0:15]],columns=['id', 'title', 'purpose', 'total_enrollment', 'rating', 'number_ratings', 'last_update_date', 'what_you_get', 'prerequisites', 'description', 'five_stars', 'four_stars', 'three_stars', 'two_stars', 'one_star'])
        df =pd.concat([df, s], ignore_index=True) 

#df = df.iloc[1: , :]
#df.set_index('id', inplace=True)

# %%
df['description_clean'] = df['description'].apply(clean)

# %%
df2 = pd.read_csv('C:/Users/15512/course_list_all.tsv', sep='\t')

# %%
complete_data = pd.concat([df, df2[:427]], axis = 'columns')

# %%
complete_data.shape
# Out:
# (427, 26)

# %%
complete_data.columns
# Out:
# Index(['id', 'title', 'purpose', 'total_enrollment', 'rating',
#        'number_ratings', 'last_update_date', 'what_you_get', 'prerequisites',
#        'description', 'five_stars', 'four_stars', 'three_stars', 'two_stars',
#        'one_star', 'description_clean', 'id', 'name', 'link', 'seller',
#        'price', 'original_price', 'lectures', 'hours', 'level',
#        'Tue Dec 14 05:56:01 2021'],
#       dtype='object')

# %%
complete_data.drop(complete_data.columns[[4, 5, 16, 17, 25]], axis = 1, inplace=True)

# %%
complete_data
# Out:
#                                                  title  \
# 0    Machine Learning A Z   Hands On Python   R In ...
# 1    Python for Data Science and Machine Learning B...
# 2    The Data Science Course 2021  Complete Data Sc...
# 3    R Programming A Z   R For Data Science With Re...
# 4    Deep Learning A Z   Hands On Artificial Neural...
# ..                                                 ...
# 422   Time Series Analysis and Forecasting with Python
# 423  Artificial Intelligence in Arabic             ...
# 424  Natural Language Processing  NLP In Python wit...
# 425  100  Exercises   Python Programming   Data Sci...
# 426  2022 Python and Machine Learning in Financial ...
#
#                                                purpose total_enrollment  \
# 0    Learn to create Machine Learning Algorithms in...           833575
# 1    Learn how to use NumPy, Pandas, Seaborn , Matp...           501618
# 2    Complete Data Science Training: Mathematics, S...           452453
# 3    Learn Programming In R And R Studio. Data Anal...           221022
# 4    Learn to create Deep Learning Algorithms in Py...           322765
# ..                                                 ...              ...
# 422  Learn Python for Pandas, Statsmodels, ARIMA, S...             3492
# 423  تعلم مبادئ الذكاء الصناعي عن طريق ١٠ مشاريع عملية              998
# 424  Learn NLP with Machine Learning Algorithms, Sp...            19672
# 425  Improve your Python programming and data scien...            40347
# 426  Using Python and machine learning in financial...            25904
#
#     last_update_date                                       what_you_get  \
# 0            12/2021  Master Machine Learning on Python   R Have a g...
# 1             5/2020  Use Python for Data Science and Machine Learni...
# 2            11/2021  The course provides the entire toolbox you nee...
# 3            12/2021  Learn to program in R at a good level Learn ho...
# 4            12/2021  Understand the intuition behind Artificial Neu...
# ..               ...                                                ...
# 422           8/2021  Basic Packages  NumPy  Pandas   Matplotlib Tim...
# 423           2/2019  Numpy  pandas  matplotlib  seaborn            ...
# 424           7/2021  Get to learn about different Applications of N...
# 425          12/2021  solve over 100 exercises in NumPy deal with re...
# 426           9/2021  You will be able to use the functions provided...
#
#                                          prerequisites  \
# 0    Requirements Just some high school mathematics...
# 1    Requirements Some programming experience Admin...
# 2    Requirements No prior experience is required  ...
# 3                                         Requirements
# 4                                         Requirements
# ..                                                 ...
# 422       Requirements General and Basic Python Skills
# 423                                       Requirements
# 424                                       Requirements
# 425  Requirements completed course  200  Exercises ...
# 426                                       Requirements
#
#                                            description five_stars four_stars  \
# 0    Description Interested in the field of Machine...        54%        34%
# 1    Description Are you ready to start your path t...        56%        36%
# 2    Description The Problem Data scientist is one ...        54%        35%
# 3    Description Learn R Programming by doing! Ther...        59%        33%
# 4    Description *** As seen on Kickstarter *** Art...        54%        34%
# ..                                                 ...        ...        ...
# 422  Description "Time Series Analysis and Forecast...        84%        12%
# 423  Description كورس كامل لتعليم مبادئ الذكاء الصن...        68%        21%
# 424  Description Interested in Learning Natural Lan...        64%        22%
# 425  Description ----------------------------------...        48%        26%
# 426  Description In this course, you will become fa...        57%        26%
#
#     three_stars two_stars one_star  \
# 0            9%        2%       1%
# 1            7%        1%     < 1%
# 2            9%        1%       1%
# 3            6%        1%       1%
# 4            9%        2%       1%
# ..          ...       ...      ...
# 422          3%        0%       1%
# 423          6%        1%       4%
# 424         11%        1%       2%
# 425         19%        4%       3%
# 426         12%        4%       1%
#
#                                      description_clean  \
# 0    interested field machine learning course cours...
# 1    ready start path becoming data scientist compr...
# 2    problem data scientist one best suited profess...
# 3    learn r programming lot r course lecture howev...
# 4     seen kickstarter artificial intelligence grow...
# ..                                                 ...
# 422   time series analysis forecasting python cours...
# 423  كورس كامل لتعليم مبادئ الذكاء الصناعي بالبايثو...
# 424  interested learning natural language processin...
# 425   recommended learning path python developer 20...
# 426  course become familiar variety date financial ...
#
#                                                   link  \
# 0        https://www.udemy.com/course/machinelearning/
# 1    https://www.udemy.com/course/python-for-data-s...
# 2    https://www.udemy.com/course/the-data-science-...
# 3          https://www.udemy.com/course/r-programming/
# 4           https://www.udemy.com/course/deeplearning/
# ..                                                 ...
# 422  https://www.udemy.com/course/time-series-analy...
# 423  https://www.udemy.com/course/artificial-intell...
# 424  https://www.udemy.com/course/nlp-bootcamp-mach...
# 425  https://www.udemy.com/course/100-exercises-pyt...
# 426  https://www.udemy.com/course/python-and-machin...
#
#                                                 seller  price  original_price  \
# 0    Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99           84.99
# 1                                        Jose Portilla  13.99           84.99
# 2                        365 Careers  365 Careers Team  15.99           94.99
# 3        Kirill Eremenko  Ligency I Team  Ligency Team  13.99           84.99
# 4    Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99           84.99
# ..                                                 ...    ...             ...
# 422                                     Navid Shirzadi  13.99           84.99
# 423  Dr  Ryan Ahmed  Ph D   MBA  Mitchell Bouchard ...  13.99           84.99
# 424                               Data Is Good Academy  13.99           19.99
# 425                Pawe  Krakowiak  takeITeasy Academy  13.99           19.99
# 426                                 S Emadedin Hashemi  13.99           84.99
#
#      lectures     hours       level
# 0         320     44.5   All Levels
# 1         165       25   All Levels
# 2         488       30   All Levels
# 3          82     10.5   All Levels
# 4         173     22.5   All Levels
# ..        ...       ...         ...
# 422        51     10.5   All Levels
# 423        57       10   All Levels
# 424        62        3     Beginner
# 425       118  1 total     Beginner
# 426        82     20.5   All Levels
#
# [427 rows x 20 columns]

# %%
def Recommend():
    input_string = input('Enter the description of Udemy Course:')
    input_string_clean = clean(input_string)
    input_string_v = tfidf_trans.transform([input_string_clean])
    cosine_simil = cosine_similarity(input_string_v, X_tfidf)[0]
    sorted_index= np.argsort(cosine_simil)[::-1]
    #return [df[df.columns][i] for i in sorted_index]
    return pd.DataFrame([complete_data.iloc[i].to_numpy().T for i in sorted_index], columns = complete_data.columns).head()

# %%
tfidf_trans=TfidfVectorizer()
X_tfidf=tfidf_trans.fit_transform(df['description_clean'])

# %%
X_tfidf
# Out:
# <427x4028 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24818 stored elements in Compressed Sparse Row format>

# %%
input_string_v = tfidf_trans.transform([stri])

# %%
cosine_simil = cosine_similarity(input_string_v, X_tfidf)[0]

# %%
sorted_index
# Out:
# array([209, 213,  87, 341, 346, 373, 354, 292, 156, 246, 152, 261, 349,
#         44, 110,  91,   1, 348,  12, 183, 278, 289, 304, 181, 267, 173,
#        235, 170, 413, 394,  73, 132, 269, 333,  41,  27,  76, 224, 232,
#         92, 238,  95, 211, 108, 356, 359, 169, 231, 401, 230, 220, 142,
#        117, 291, 282, 205, 178,  70, 360, 340, 249, 175,  36, 300, 258,
#         32, 208, 317, 195,  18, 148,   5, 368,  28, 171, 281,  53, 260,
#        201, 365, 221, 352,  35, 140, 145, 147, 222, 279, 157,  31, 121,
#        179, 405, 273, 361, 339, 137, 262,   2,  50,  90,   6, 103, 143,
#        182, 187,  74,  21, 287, 408, 312, 329, 129,  60, 283,   7, 168,
#         83, 421,   0, 155,  67, 115,  33, 134,  78, 396, 180, 252, 351,
#        275, 345, 302, 199, 295, 189,  49, 177, 386, 301, 165,  68, 350,
#        383,  46, 372, 122, 307, 424, 223, 225,  11, 306, 290, 331, 322,
#         69, 196,  39, 328,  13, 390, 332, 305, 164, 276, 342,  93,  96,
#        174, 309, 318, 286, 410,  97, 422,  23, 188, 192,  30, 362, 400,
#        159, 313, 397, 172,  72, 395, 353, 335, 207,  20, 338, 161, 293,
#         52, 311, 412,  15, 392,  17, 212, 285,  51, 380, 416, 324, 218,
#        382,  85,  65, 219, 202, 325, 184, 323, 149, 381,  22, 259,  79,
#        120, 154, 411, 409, 109, 203, 321, 363, 253, 135, 407, 200, 229,
#        303, 316, 153,  89,  40, 139,  61,  45, 319,  63,  98, 337, 389,
#         94, 138, 425,  75,  55, 358, 418,  54, 131,  48,  26, 277, 206,
#         29, 299, 176, 248, 310,  56,  58, 228, 210, 105, 193, 163, 315,
#        123,  80, 406, 426, 255, 272, 326, 327, 244, 130, 106,  66, 265,
#        256, 347, 271,  42,  43, 364, 366, 270,  47, 344, 268, 404, 266,
#        257, 264, 403, 367,  38, 369, 370,  57, 371,  59, 402, 167, 263,
#         62, 166,  64, 336, 320,  37, 294, 296,  14, 297, 185, 298,  10,
#          9,   8, 419, 420, 186,   4,   3, 423, 308,  16, 417, 274,  19,
#         34, 204, 198, 280, 197, 357, 414, 415, 355,  25,  24, 314, 284,
#        288, 194,  71, 398, 399, 376, 128, 127, 126, 125, 124, 216, 236,
#        385, 237, 119, 118, 330, 116, 239, 114, 384, 217, 234, 141, 377,
#        146, 378, 144, 379, 226, 227, 133, 150, 151, 375, 136, 334, 233,
#        113, 112, 111,  82, 214,  88, 247,  86, 160,  84,  81, 245, 162,
#        250, 251,  77, 254, 343, 393, 391, 387, 102, 240, 388, 107, 374,
#        104, 215, 101, 191, 100,  99, 158, 241, 242, 243, 190], dtype=int64)

# %%
sorted_index=np.argsort(cosine_simil)[::-1]

# %%
pd.DataFrame([df.iloc[i].to_numpy().T for i in sorted_index], columns = df.columns)
# Out:
#       id                                              title  \
# 0    210  Complete Data Science Course  Beginner to Advance
# 1    214  Build 30 Real World Data Science   Machine Lea...
# 2     88  Complete Data Science Training with Python for...
# 3    342  Data Science A Z   Machine Learning with Pytho...
# 4    347           Data Science with Python Complete Course
# ..   ...                                                ...
# 422  159                           TensorFlow 2 0 Practical
# 423  242  Complete Machine Learning Course   Learn From ...
# 424  243          Machine Learning with Python from Scratch
# 425  244  Statistics in R   The R Language for Statistic...
# 426  191  Deep Learning for Computer Vision with TensorF...
#
#                                                purpose total_enrollment  \
# 0    Learn Data Science like a professional! Start ...            31455
# 1    Practical Data Science Course: Learn To Build ...            27431
# 2    Beginners python data analytics : Data science...             8128
# 3    By Data Scientist / IITian for Beginners . Dat...              665
# 4            Data Science 2021 : Complete Data Science            35577
# ..                                                 ...              ...
# 422  Master Tensorflow 2.0, Google’s most powerful ...             5311
# 423  Learn Machine Learning from scratch and go fro...            31289
# 424  Mastering Machine Learning Algorithms includin...             4324
# 425  Statistics made easy with the open source R la...             3168
# 426  ConvNets, ResNet, Inception, Faster R-CNN, SSD...             3018
#
#     rating number_ratings last_update_date  \
# 0     NULL           NULL           8/2019
# 1     NULL           NULL          11/2021
# 2     NULL           NULL          10/2021
# 3     NULL           NULL           3/2020
# 4     NULL           NULL           9/2021
# ..     ...            ...              ...
# 422   NULL           NULL           2/2021
# 423   NULL           NULL           6/2019
# 424   NULL           NULL           1/2021
# 425   NULL           NULL          11/2018
# 426   NULL           NULL          12/2021
#
#                                           what_you_get  \
# 0    Basics Of Data Science Programming   Data Scie...
# 1    Create supervised machine learning algorithms ...
# 2    Python data analytics   Install Anaconda   Wor...
# 3    Data Science   Machine Learning How to do mach...
# 4    Perform high level mathematical and technical ...
# ..                                                 ...
# 422  Master Google s newly released TensorFlow 2 0 ...
# 423  Learn The Basics Learn Advanced Methods Step B...
# 424  Have an understand of Machine Learning and how...
# 425  know which statistical test to use for a given...
# 426  Learn about the state of the art models in obj...
#
#                                          prerequisites  \
# 0    Requirements Being able to use a Pc or Mac at ...
# 1    Requirements Interest in Machine Learning Basi...
# 2                                         Requirements
# 3                         Requirements No Prerequisite
# 4    Requirements An understanding of the fundament...
# ..                                                 ...
# 422           Requirements PC with internet connection
# 423  Requirements Basic It Skill  Example  Being ab...
# 424  Requirements Basic knowledge of Python Basic k...
# 425  Requirements solid understanding of R programm...
# 426  Requirements Machine Learning concepts  Linear...
#
#                                            description five_stars four_stars  \
# 0    Description Welcome to my course "Complete Dat...        15%        16%
# 1    Description What is Data Science? Data science...        31%        30%
# 2    Description Complete Guide to Practical Data S...        49%        30%
# 3    Description Interested in the field of Data Sc...        44%        29%
# 4    Description Today Data Science and Machine Lea...        45%        37%
# ..                                                 ...        ...        ...
# 422  Description Artificial Intelligence (AI) revol...        47%        38%
# 423  Description Welcome to this course "Complete M...        25%        32%
# 424  Description Machine Learning is a hot topic!  ...        31%        40%
# 425  Description Do you want to learn more about st...        40%        35%
# 426  Description This course is focused in the appl...        42%        35%
#
#     three_stars two_stars one_star  \
# 0           26%       12%      31%
# 1           27%        6%       6%
# 2           14%        4%       3%
# 3           17%        6%       4%
# 4           13%        5%       0%
# ..          ...       ...      ...
# 422         11%        3%       1%
# 423         21%        7%      15%
# 424         19%        5%       5%
# 425         17%        3%       5%
# 426         14%        3%       6%
#
#                                      description_clean
# 0    welcome course complete data science course be...
# 1    data science data science domain study deal va...
# 2    complete guide practical data science python l...
# 3    interested field data science machine learning...
# 4    today data science machine learning used almos...
# ..                                                 ...
# 422  artificial intelligence ai revolution tensorfl...
# 423  welcome course complete machine learning cours...
# 424  machine learning hot topic python developer un...
# 425  want learn statistical programming quantitativ...
# 426  course focused application deep learning image...
#
# [427 rows x 16 columns]

# %%
Recommend()
# Out:
# Enter the description of Udemy Course:You've definitely heard of AI and Deep Learning. But when you ask yourself, what is my position with respect to this new industrial revolution, that might lead you to another fundamental question: am I a consumer or a creator? For most people nowadays, the answer would be, a consumer.  But what if you could also become a creator?  What if there was a way for you to easily break into the World of Artificial Intelligence and build amazing applications which leverage the latest technology to make the World a better place?  Sounds too good to be true, doesn't it?  But there actually is a way..  Computer Vision is by far the easiest way of becoming a creator.  And it's not only the easiest way, it's also the branch of AI where there is the most to create.  Why? You'll ask.  That's because Computer Vision is applied everywhere. From health to retail to entertainment - the list goes on. Computer Vision is already a $18 Billion market and is growing exponentially.  Just think of tumor detection in patient MRI brain scans. How many more lives are saved every day simply because a computer can analyze 10,000x more images than a human?  And what if you find an industry where Computer Vision is not yet applied? Then all the better! That means there's a business opportunity which you can take advantage of.  So now that raises the question: how do you break into the World of Computer Vision?  Up until now, computer vision has for the most part been a maze. A growing maze.  As the number of codes, libraries and tools in CV grows, it becomes harder and harder to not get lost.  On top of that, not only do you need to know how to use it - you also need to know how it works to maximise the advantage of using Computer Vision.  To this problem we want to bring...   Computer Vision A-Z.  With this brand new course you will not only learn how the most popular computer vision methods work, but you will also learn to apply them in practice!  Can't wait to see you inside the class,
#                                                title  \
# 0  Deep Learning and Computer Vision A Z   OpenCV...
# 1                        Computer Vision Masterclass
# 2  Computer Vision In Python  Face Detection   Im...
# 3  Computer Vision  Face Recognition Quick Starte...
# 4  Automated Multiple Face Recognition AI Using P...
#
#                                              purpose total_enrollment  \
# 0  Become a Wizard of all the latest Computer Vis...            43258
# 1  Learn in practice everything you need to know ...            26710
# 2  Learn Computer Vision With OpenCV In Python! M...            16702
# 3  Quickly Build Python Deep Learning based Face ...             3229
# 4  Learn about OpenCv Basics, Face Recognition in...            19677
#
#   last_update_date                                       what_you_get  \
# 0          12/2021  Have a toolbox of the most powerful Computer V...
# 1          10/2021  Understand the basic intuition about Cascade a...
# 2           8/2021  Use OpenCV to work with image files Understand...
# 3          12/2021  Face Detection from Images Face Detection from...
# 4          11/2019  Automated Multiple Face Recognition in an imag...
#
#                                        prerequisites  \
# 0  Requirements Only High School Maths Basic Pyth...
# 1  Requirements Programming logic Basic Python pr...
# 2    Requirements Basic Python programming knowledge
# 3  Requirements A decent configuration computer a...
# 4          Requirements Basics of Python Programming
#
#                                          description five_stars four_stars  \
# 0  Description *** AS SEEN ON KICKSTARTER *** You...        53%        32%
# 1  Description Computer Vision is a subarea of Ar...        51%        33%
# 2  Description Computer vision is an interdiscipl...        46%        39%
# 3  Description Hi There!  welcome to my new cours...        45%        42%
# 4  Description Hello, welcome to the Amazing worl...        27%        31%
#
#   three_stars two_stars one_star  \
# 0         10%        3%       2%
# 1         13%        2%       1%
# 2         11%        3%       1%
# 3         10%        2%       1%
# 4         27%        9%       6%
#
#                                    description_clean  \
# 0   seen kickstarter definitely heard ai deep lea...
# 1  computer vision subarea artificial intelligenc...
# 2  computer vision interdisciplinary field deal c...
# 3  hi welcome new course face recognition deep le...
# 4  hello welcome amazing world computer vision co...
#
#                                                 link  \
# 0  https://www.udemy.com/course/computer-vision-a-z/
# 1  https://www.udemy.com/course/computer-vision-m...
# 2  https://www.udemy.com/course/computer-vision-i...
# 3  https://www.udemy.com/course/computer-vision-f...
# 4  https://www.udemy.com/course/automated-multipl...
#
#                                               seller  price  original_price  \
# 0  Hadelin de Ponteves  Kirill Eremenko  Ligency ...  13.99           84.99
# 1      Jones Granatyr  Ligency I Team  Gabriel Alves  13.99           84.99
# 2                     Emenwa Global  Zoolord Academy  13.99           84.99
# 3                                    Abhilash Nelson  15.99           99.99
# 4                     Nishit Maru  Three Millennials  13.99           84.99
#
#    lectures  hours       level
# 0        85    11   All Levels
# 1       228  25.5   All Levels
# 2        61    11   All Levels
# 3        64   6.5   All Levels
# 4        10     2   All Levels

# %%
columns = df.columns

# %%
cols = list(columns)

# %%
cols
# Out:
# ['id',
#  'title',
#  'purpose',
#  'total_enrollment',
#  'rating',
#  'number_ratings',
#  'last_update_date',
#  'what_you_get',
#  'prerequisites',
#  'description',
#  'five_stars',
#  'four_stars',
#  'three_stars',
#  'two_stars',
#  'one_star',
#  'description_clean']

# %%
df2 = pd.read_csv('C:/Users/15512/course_list_all.tsv', sep='\t')

# %%
df2
# Out:
#         id                                               name  \
# 0        1                                   machinelearning/
# 1        2  python-for-data-science-and-machine-learning-b...
# 2        3  the-data-science-course-complete-data-science-...
# 3        4                                     r-programming/
# 4        5                                      deeplearning/
# ...    ...                                                ...
# 2187  2188                        master-en-machine-learning/
# 2188  2189                          data-science-foundations/
# 2189  2190         introduccion-gratuita-python-data-science/
# 2190  2191     guia-iniciantes-machine-learning-data-science/
# 2191  2192                      introduccion-al-data-science/
#
#                                                    link  \
# 0         https://www.udemy.com/course/machinelearning/
# 1     https://www.udemy.com/course/python-for-data-s...
# 2     https://www.udemy.com/course/the-data-science-...
# 3           https://www.udemy.com/course/r-programming/
# 4            https://www.udemy.com/course/deeplearning/
# ...                                                 ...
# 2187  https://www.udemy.com/course/master-en-machine...
# 2188  https://www.udemy.com/course/data-science-foun...
# 2189  https://www.udemy.com/course/introduccion-grat...
# 2190  https://www.udemy.com/course/guia-iniciantes-m...
# 2191  https://www.udemy.com/course/introduccion-al-d...
#
#                                                  seller  price  \
# 0     Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99
# 1                                         Jose Portilla  13.99
# 2                         365 Careers  365 Careers Team  15.99
# 3         Kirill Eremenko  Ligency I Team  Ligency Team  13.99
# 4     Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99
# ...                                                 ...    ...
# 2187  Juan Gabriel Gomila Salas  Mar a Santos  Arnau...   Free
# 2188                                Eng  Mustafa Othman   Free
# 2189                            Rafael Gonzalez Gouveia   Free
# 2190                  Jones Granatyr  IA Expert Academy   Free
# 2191                          Pedro Daniel Alcal  Rojas   Free
#
#       original_price  lectures     hours       level  Tue Dec 14 05:56:01 2021
# 0              84.99       320     44.5   All Levels                       NaN
# 1              84.99       165       25   All Levels                       NaN
# 2              94.99       488       30   All Levels                       NaN
# 3              84.99        82     10.5   All Levels                       NaN
# 4              84.99       173     22.5   All Levels                       NaN
# ...              ...       ...       ...         ...                       ...
# 2187             NaN        73     16.5     Beginner                       NaN
# 2188             NaN        11        2     Beginner                       NaN
# 2189             NaN        13  1 total     Beginner                       NaN
# 2190             NaN        28        2     Beginner                       NaN
# 2191             NaN        15      1.5   All Levels                       NaN
#
# [2192 rows x 10 columns]

# %%
complete_df123456 = pd.concat([df, df2[:427]], axis = 'columns')

# %%
complete_df123456
# Out:
#       id                                              title  \
# 0      1  Machine Learning A Z   Hands On Python   R In ...
# 1      2  Python for Data Science and Machine Learning B...
# 2      3  The Data Science Course 2021  Complete Data Sc...
# 3      4  R Programming A Z   R For Data Science With Re...
# 4      5  Deep Learning A Z   Hands On Artificial Neural...
# ..   ...                                                ...
# 422  423   Time Series Analysis and Forecasting with Python
# 423  424  Artificial Intelligence in Arabic             ...
# 424  425  Natural Language Processing  NLP In Python wit...
# 425  426  100  Exercises   Python Programming   Data Sci...
# 426  427  2022 Python and Machine Learning in Financial ...
#
#                                                purpose total_enrollment  \
# 0    Learn to create Machine Learning Algorithms in...           833575
# 1    Learn how to use NumPy, Pandas, Seaborn , Matp...           501618
# 2    Complete Data Science Training: Mathematics, S...           452453
# 3    Learn Programming In R And R Studio. Data Anal...           221022
# 4    Learn to create Deep Learning Algorithms in Py...           322765
# ..                                                 ...              ...
# 422  Learn Python for Pandas, Statsmodels, ARIMA, S...             3492
# 423  تعلم مبادئ الذكاء الصناعي عن طريق ١٠ مشاريع عملية              998
# 424  Learn NLP with Machine Learning Algorithms, Sp...            19672
# 425  Improve your Python programming and data scien...            40347
# 426  Using Python and machine learning in financial...            25904
#
#     rating number_ratings last_update_date  \
# 0     NULL           NULL          12/2021
# 1     NULL           NULL           5/2020
# 2     NULL           NULL          11/2021
# 3     NULL           NULL          12/2021
# 4     NULL           NULL          12/2021
# ..     ...            ...              ...
# 422   NULL           NULL           8/2021
# 423   NULL           NULL           2/2019
# 424   NULL           NULL           7/2021
# 425   NULL           NULL          12/2021
# 426   NULL           NULL           9/2021
#
#                                           what_you_get  \
# 0    Master Machine Learning on Python   R Have a g...
# 1    Use Python for Data Science and Machine Learni...
# 2    The course provides the entire toolbox you nee...
# 3    Learn to program in R at a good level Learn ho...
# 4    Understand the intuition behind Artificial Neu...
# ..                                                 ...
# 422  Basic Packages  NumPy  Pandas   Matplotlib Tim...
# 423  Numpy  pandas  matplotlib  seaborn            ...
# 424  Get to learn about different Applications of N...
# 425  solve over 100 exercises in NumPy deal with re...
# 426  You will be able to use the functions provided...
#
#                                          prerequisites  \
# 0    Requirements Just some high school mathematics...
# 1    Requirements Some programming experience Admin...
# 2    Requirements No prior experience is required  ...
# 3                                         Requirements
# 4                                         Requirements
# ..                                                 ...
# 422       Requirements General and Basic Python Skills
# 423                                       Requirements
# 424                                       Requirements
# 425  Requirements completed course  200  Exercises ...
# 426                                       Requirements
#
#                                            description  ...   id  \
# 0    Description Interested in the field of Machine...  ...    1
# 1    Description Are you ready to start your path t...  ...    2
# 2    Description The Problem Data scientist is one ...  ...    3
# 3    Description Learn R Programming by doing! Ther...  ...    4
# 4    Description *** As seen on Kickstarter *** Art...  ...    5
# ..                                                 ...  ...  ...
# 422  Description "Time Series Analysis and Forecast...  ...  423
# 423  Description كورس كامل لتعليم مبادئ الذكاء الصن...  ...  424
# 424  Description Interested in Learning Natural Lan...  ...  425
# 425  Description ----------------------------------...  ...  426
# 426  Description In this course, you will become fa...  ...  427
#
#                                                   name  \
# 0                                     machinelearning/
# 1    python-for-data-science-and-machine-learning-b...
# 2    the-data-science-course-complete-data-science-...
# 3                                       r-programming/
# 4                                        deeplearning/
# ..                                                 ...
# 422  time-series-analysis-and-forecasting-with-python/
# 423                 artificial-intelligence-in-arabic/
# 424       nlp-bootcamp-machine-learning-deep-learning/
# 425  100-exercises-python-programming-data-science-...
# 426  python-and-machine-learning-in-financial-analy...
#
#                                                   link  \
# 0        https://www.udemy.com/course/machinelearning/
# 1    https://www.udemy.com/course/python-for-data-s...
# 2    https://www.udemy.com/course/the-data-science-...
# 3          https://www.udemy.com/course/r-programming/
# 4           https://www.udemy.com/course/deeplearning/
# ..                                                 ...
# 422  https://www.udemy.com/course/time-series-analy...
# 423  https://www.udemy.com/course/artificial-intell...
# 424  https://www.udemy.com/course/nlp-bootcamp-mach...
# 425  https://www.udemy.com/course/100-exercises-pyt...
# 426  https://www.udemy.com/course/python-and-machin...
#
#                                                 seller  price original_price  \
# 0    Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99          84.99
# 1                                        Jose Portilla  13.99          84.99
# 2                        365 Careers  365 Careers Team  15.99          94.99
# 3        Kirill Eremenko  Ligency I Team  Ligency Team  13.99          84.99
# 4    Kirill Eremenko  Hadelin de Ponteves  Ligency ...  13.99          84.99
# ..                                                 ...    ...            ...
# 422                                     Navid Shirzadi  13.99          84.99
# 423  Dr  Ryan Ahmed  Ph D   MBA  Mitchell Bouchard ...  13.99          84.99
# 424                               Data Is Good Academy  13.99          19.99
# 425                Pawe  Krakowiak  takeITeasy Academy  13.99          19.99
# 426                                 S Emadedin Hashemi  13.99          84.99
#
#      lectures     hours       level Tue Dec 14 05:56:01 2021
# 0         320     44.5   All Levels                      NaN
# 1         165       25   All Levels                      NaN
# 2         488       30   All Levels                      NaN
# 3          82     10.5   All Levels                      NaN
# 4         173     22.5   All Levels                      NaN
# ..        ...       ...         ...                      ...
# 422        51     10.5   All Levels                      NaN
# 423        57       10   All Levels                      NaN
# 424        62        3     Beginner                      NaN
# 425       118  1 total     Beginner                      NaN
# 426        82     20.5   All Levels                      NaN
#
# [427 rows x 26 columns]
